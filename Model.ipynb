# %%
import numpy as np  # numpy btt3aml m3 arrays
import matplotlib.pyplot as plt # btsa3dny f rsm el plots ll data
import pandas as pd  # btsa3dny a7wl bunch of dataset into a set of table, hanlding popular format of data
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
dataset = pd.read_csv('Dataset.csv')

X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, -1].values

# %%
# hanlding missing values for categories
imputerObjects = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
X[:, 1:4] = imputerObjects.fit_transform(X[:, 1:4])  # married , gender , dependent
X[:, 8:9] = imputerObjects.fit_transform(X[:, 8:9]) # property area
X[:,1:4]
# Out:
# array([['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Female', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 3.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 4.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Female', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 3.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 3.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Female', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 4.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 2.0],
#        ['Female', 'No', 0.0],
#        ['Female', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'Yes', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 1.0],
#        ['Male', 'No', 0.0],
#        ['Female', 'Yes', 1.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 2.0],
#        ['Male', 'Yes', 2.0],
#        ['Female', 'No', 0.0],
#        ['Female', 'Yes', 1.0],
#        ['Female', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'No', 0.0],
#        ['Male', 'Yes', 0.0],
#        ['Male', 'Yes', 2.0]], dtype=object)

# %%
# hanlding missing values for loan & loan amount
imputerNum = SimpleImputer(missing_values=np.nan, strategy='mean')
imputerNum.fit(X[:, 6:8])
X[:, 6:8] = imputerNum.transform(X[:, 6:8])
X[ : ,6:8]
# Out:
# array([[282.7354497354497, 360.0],
#        [128.0, 360.0],
#        [66.0, 360.0],
#        [120.0, 360.0],
#        [141.0, 360.0],
#        [267.0, 360.0],
#        [95.0, 360.0],
#        [158.0, 360.0],
#        [168.0, 360.0],
#        [349.0, 360.0],
#        [70.0, 360.0],
#        [109.0, 360.0],
#        [200.0, 360.0],
#        [114.0, 360.0],
#        [17.0, 120.0],
#        [125.0, 360.0],
#        [100.0, 240.0],
#        [76.0, 360.0],
#        [133.0, 360.0],
#        [115.0, 343.4526315789474],
#        [104.0, 360.0],
#        [315.0, 360.0],
#        [116.0, 360.0],
#        [112.0, 360.0],
#        [151.0, 360.0],
#        [191.0, 360.0],
#        [122.0, 360.0],
#        [110.0, 360.0],
#        [35.0, 360.0],
#        [120.0, 360.0],
#        [201.0, 360.0],
#        [74.0, 360.0],
#        [106.0, 360.0],
#        [114.0, 360.0],
#        [320.0, 360.0],
#        [282.7354497354497, 360.0],
#        [100.0, 343.4526315789474],
#        [144.0, 360.0],
#        [184.0, 360.0],
#        [110.0, 360.0],
#        [80.0, 360.0],
#        [47.0, 360.0],
#        [75.0, 360.0],
#        [134.0, 360.0],
#        [96.0, 343.4526315789474],
#        [88.0, 343.4526315789474],
#        [44.0, 360.0],
#        [144.0, 360.0],
#        [120.0, 360.0],
#        [144.0, 360.0],
#        [100.0, 360.0],
#        [120.0, 360.0],
#        [112.0, 360.0],
#        [134.0, 360.0],
#        [286.0, 360.0],
#        [97.0, 360.0],
#        [96.0, 360.0],
#        [135.0, 360.0],
#        [180.0, 360.0],
#        [144.0, 360.0],
#        [120.0, 360.0],
#        [99.0, 360.0],
#        [165.0, 180.0],
#        [282.7354497354497, 360.0],
#        [116.0, 360.0],
#        [258.0, 360.0],
#        [126.0, 180.0],
#        [180.0, 300.0],
#        [130.0, 360.0],
#        [111.0, 360.0],
#        [282.7354497354497, 360.0],
#        [167.0, 360.0],
#        [265.0, 360.0],
#        [50.0, 240.0],
#        [136.0, 360.0],
#        [99.0, 360.0],
#        [104.0, 360.0],
#        [210.0, 360.0],
#        [175.0, 360.0],
#        [131.0, 360.0],
#        [188.0, 180.0],
#        [81.0, 360.0],
#        [122.0, 360.0],
#        [25.0, 120.0],
#        [282.7354497354497, 360.0],
#        [137.0, 360.0],
#        [50.0, 360.0],
#        [115.0, 180.0],
#        [131.0, 360.0],
#        [133.0, 180.0],
#        [151.0, 360.0],
#        [282.7354497354497, 360.0],
#        [282.7354497354497, 360.0],
#        [160.0, 360.0],
#        [100.0, 360.0],
#        [225.0, 360.0],
#        [120.0, 360.0],
#        [216.0, 360.0],
#        [94.0, 480.0],
#        [136.0, 360.0],
#        [139.0, 360.0],
#        [152.0, 343.4526315789474],
#        [282.7354497354497, 360.0],
#        [118.0, 360.0],
#        [185.0, 180.0],
#        [154.0, 360.0],
#        [85.0, 360.0],
#        [175.0, 360.0],
#        [259.0, 360.0],
#        [180.0, 360.0],
#        [282.7354497354497, 360.0],
#        [160.0, 180.0],
#        [182.0, 360.0],
#        [650.0, 480.0],
#        [113.0, 360.0],
#        [50.0, 360.0],
#        [600.0, 180.0],
#        [160.0, 360.0],
#        [187.0, 360.0],
#        [120.0, 360.0],
#        [255.0, 360.0],
#        [98.0, 360.0],
#        [275.0, 360.0],
#        [121.0, 360.0],
#        [158.0, 360.0],
#        [75.0, 180.0],
#        [182.0, 343.4526315789474],
#        [112.0, 360.0],
#        [129.0, 360.0],
#        [63.0, 480.0],
#        [200.0, 360.0],
#        [95.0, 360.0],
#        [700.0, 300.0],
#        [81.0, 180.0],
#        [187.0, 360.0],
#        [87.0, 360.0],
#        [116.0, 360.0],
#        [101.0, 360.0],
#        [495.0, 360.0],
#        [116.0, 360.0],
#        [102.0, 480.0],
#        [180.0, 360.0],
#        [67.0, 360.0],
#        [73.0, 180.0],
#        [260.0, 360.0],
#        [108.0, 360.0],
#        [120.0, 360.0],
#        [66.0, 300.0],
#        [58.0, 360.0],
#        [120.0, 343.4526315789474],
#        [113.0, 360.0],
#        [83.0, 360.0],
#        [90.0, 360.0],
#        [16600.0, 360.0],
#        [282.7354497354497, 180.0],
#        [135.0, 360.0],
#        [124.0, 360.0],
#        [120.0, 360.0],
#        [127.0, 360.0],
#        [60.0, 360.0],
#        [116.0, 360.0],
#        [144.0, 360.0],
#        [175.0, 343.4526315789474],
#        [128.0, 360.0],
#        [170.0, 360.0],
#        [138.0, 360.0],
#        [210.0, 360.0],
#        [158.0, 480.0],
#        [200.0, 360.0],
#        [104.0, 360.0],
#        [42.0, 180.0],
#        [120.0, 343.4526315789474],
#        [280.0, 360.0],
#        [140.0, 360.0],
#        [170.0, 360.0],
#        [255.0, 360.0],
#        [122.0, 360.0],
#        [279.0, 180.0],
#        [192.0, 360.0],
#        [255.0, 360.0],
#        [115.0, 360.0],
#        [94.0, 360.0],
#        [304.0, 360.0],
#        [128.0, 360.0],
#        [330.0, 360.0],
#        [134.0, 360.0],
#        [155.0, 36.0],
#        [120.0, 360.0],
#        [128.0, 360.0],
#        [151.0, 360.0],
#        [150.0, 360.0],
#        [160.0, 360.0],
#        [135.0, 360.0],
#        [90.0, 360.0],
#        [30.0, 360.0],
#        [136.0, 360.0],
#        [126.0, 360.0],
#        [150.0, 360.0],
#        [9000.0, 360.0]], dtype=object)

# %%
le = LabelEncoder()
for i in range(3): 
    X[:, i] = le.fit_transform(X[:, i])
X[:,9] = le.fit_transform(X[:,9]) # encode property area
X[:]
# Out:
# array([[0, 1, 0, ..., 360.0, 1.0, 2],
#        [1, 1, 1, ..., 360.0, 1.0, 0],
#        [2, 1, 1, ..., 360.0, 1.0, 2],
#        ...,
#        [196, 1, 0, ..., 360.0, 1.0, 0],
#        [197, 1, 1, ..., 360.0, 1.0, 1],
#        [198, 1, 1, ..., 360.0, 1.0, 1]], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test= sc.transform(X_test)
X_train 
X_test
# Out:
# array([[-1.42055634e+00,  4.59763106e-01,  6.57793514e-01,
#         -6.27308243e-01, -8.83274138e-02, -7.91711546e-01,
#         -1.17002864e-01,  3.01684148e-01,  3.82300727e-01,
#         -1.49282224e+00],
#        [ 1.23424033e+00,  4.59763106e-01,  6.57793514e-01,
#          3.67042057e-01, -5.12292350e-01,  2.34388353e-01,
#         -1.56789083e-01,  3.01684148e-01,  3.82300727e-01,
#         -2.07096727e-01],
#        [ 1.26609930e-01,  4.59763106e-01,  6.57793514e-01,
#         -1.26606434e-01, -2.60898458e+00, -2.61574182e+00,
#          1.07862879e+00],
#        [-1.27990486e+00,  4.59763106e-01,  6.57793514e-01,
#         -6.27308243e-01, -4.57792683e-01,  3.33801147e-01,
#         -1.32094188e-01,  3.01684148e-01,  3.82300727e-01,
#         -2.07096727e-01],
#        [ 5.66145802e-01,  4.59763106e-01,  6.57793514e-01,
#         -6.27308243e-01, -6.31023765e-01,  9.20132451e-02,
#         -1.69136530e-01,  3.01684148e-01,  3.82300727e-01,
#         -1.49282224e+00],
#        [ 8.29867325e-01,  4.59763106e-01,  6.57793514e-01,
#         -6.27308243e-01,  5.97387572e+00,  1.58120691e+00,
#         -1.34838066e-01,  3.01684148e-01,  3.82300727e-01,
#         -2.07096727e-01],
#        [-6.29391769e-01,  4.59763106e-01,  6.57793514e-01,
#          3.67042057e-01, -7.80644896e-02, -7.91711546e-01,
#          8.84249757e-02,  3.01684148e-01, -2.61574182e+00,
#         -1.49282224e+00],
#        [-1.59637069e+00,  4.59763106e-01,  6.57793514e-01,
#          1.36139236e+00, -2.44217693e-01, -2.93802677e-02,
#         -6.89850139e-02,  3.01684148e-01,  3.82300727e-01,
#          1.07862879e+00],
#        [-4.18414551e-01,  4.59763106e-01,  6.57793514e-01,
#          1.36139236e+00, -3.63303002e-01,  2.07412017e-01,
#         -1.63648776e-01,  3.01684148e-01,  3.82300727e-01,
#         -2.07096727e-01],
#        [-1.40415487e-02,  4.59763106e-01,  6.57793514e-01,
#          2.35574266e+00, -5.86610076e-01, -4.15041963e-01,
#         -1.70508469e-01,  2.24212997e+00,  3.82300727e-01,
#         -2.07096727e-01],
#        [ 1.18149602e+00,  4.59763106e-01,  6.57793514e-01,
#          1.36139236e+00,  1.52851304e-01,  5.50456733e-02,
#         -1.13635936e-02,  3.01684148e-01,  3.82300727e-01,
#         -2.07096727e-01]])

# %%
Classifier = KNeighborsClassifier(n_neighbors = 7)
Classifier.fit(X_train , y_train)
y_pred = Classifier.predict(X_test)
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y'],
#       dtype=object)

# %%
print ('Accuracy: ', accuracy_score(y_test,y_pred))
print ("\n Classification Report: \n",classification_report(y_test , y_pred))
cm = confusion_matrix(y_test, y_pred)
print ('\nConfusion Matrix: \n', cm)
# Out:
# Accuracy:  0.86
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.89      0.57      0.70        14
#            Y       0.85      0.97      0.91        36
#
#     accuracy                           0.86        50
#    macro avg       0.87      0.77      0.80        50
# weighted avg       0.86      0.86      0.85        50
#
#
# Confusion Matrix:
#  [[ 8  6]
#  [ 1 35]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidths=.5, cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Values')
plt.show()
